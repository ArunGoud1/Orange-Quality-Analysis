# %% [markdown]
# ## Orange Quality Analysis  🍊

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt              
import seaborn as sns

# %%
Orange = pd.read_csv("Orange Quality Data.csv")

# %%
Orange.head()
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
# 2        6.8         150              14.0           3.0             1.0
# 3        9.0         250               8.5           3.8             4.0
# 4        8.5         210              11.5           3.3             2.5
#
#    HarvestTime (days)  Ripeness (1-5)         Color       Variety  \
# 0                  10             4.0        Orange      Valencia
# 1                  14             4.5   Deep Orange         Navel
# 2                   7             5.0  Light Orange     Cara Cara
# 3                  21             3.5    Orange-Red  Blood Orange
# 4                  12             5.0        Orange        Hamlin
#
#   Blemishes (Y/N)  Quality (1-5)
# 0               N            4.0
# 1               N            4.5
# ...

# %%
Orange.tail()
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
#      HarvestTime (days)  Ripeness (1-5)         Color            Variety  \
# 236                  13             1.0    Orange-Red          Tangerine
# 237                  20             5.0  Light Orange  Minneola (Hybrid)
# 238                  13             3.0   Deep Orange             Temple
# 239                  23             1.0  Light Orange       Moro (Blood)
# 240                  21             2.0    Orange-Red              Jaffa
#
#              Blemishes (Y/N)  Quality (1-5)
# ...

# %%
Orange.shape
# Out:
# (241, 11)

# %%
Orange.describe()
# Out:
#         Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# count  241.000000  241.000000        241.000000    241.000000      241.000000
# mean     7.844813  205.128631         10.907884      3.473900        3.072614
# std      1.086002   56.461012          2.760446      0.421007        1.323630
# min      6.000000  100.000000          5.500000      2.800000        1.000000
# 25%      6.900000  155.000000          8.500000      3.200000        2.000000
# 50%      7.800000  205.000000         11.000000      3.400000        3.000000
# 75%      8.700000  252.000000         13.400000      3.800000        4.000000
# max     10.000000  300.000000         16.000000      4.400000        5.000000
#
#        HarvestTime (days)  Ripeness (1-5)  Quality (1-5)
# count          241.000000      241.000000     241.000000
# mean            15.344398        3.599585       3.817427
# std              5.323852        1.205214       1.014410
# ...

# %%
Orange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Size (cm)           241 non-null    float64
#  1   Weight (g)          241 non-null    int64
#  2   Brix (Sweetness)    241 non-null    float64
#  3   pH (Acidity)        241 non-null    float64
#  4   Softness (1-5)      241 non-null    float64
#  5   HarvestTime (days)  241 non-null    int64
#  6   Ripeness (1-5)      241 non-null    float64
#  7   Color               241 non-null    object
#  8   Variety             241 non-null    object
#  9   Blemishes (Y/N)     241 non-null    object
#  10  Quality (1-5)       241 non-null    float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 20.8+ KB

# %%
Orange.isna().any()
# Out:
# Size (cm)             False
# Weight (g)            False
# Brix (Sweetness)      False
# pH (Acidity)          False
# Softness (1-5)        False
# HarvestTime (days)    False
# Ripeness (1-5)        False
# Color                 False
# Variety               False
# Blemishes (Y/N)       False
# Quality (1-5)         False
# dtype: bool

# %%
Orange.isna().sum()
# Out:
# Size (cm)             0
# Weight (g)            0
# Brix (Sweetness)      0
# pH (Acidity)          0
# Softness (1-5)        0
# HarvestTime (days)    0
# Ripeness (1-5)        0
# Color                 0
# Variety               0
# Blemishes (Y/N)       0
# Quality (1-5)         0
# dtype: int64

# %% [markdown]
# ## Questions
# 1) Is there a correlation between the size (Size (cm)) and the weight (Weight (g)) of the fruit.
# 2) How does the sweetness (Brix) of the fruit correlate with its acidity (pH)? Do sweeter fruits have lower acidity.
# 3)  How does the softness (Softness (1-5)) of the fruit relate to its ripeness (Ripeness (1-5)).
# 4)  Do fruits with blemishes (Blemishes (Y/N)) tend to have lower ripeness or softness levels.
# 5)  How do different fruit varieties (Variety) differ in terms of size, weight, sweetness, acidity, and ripeness.

# %% [markdown]
# ## Is there a correlation between the size (Size (cm)) and the weight (Weight (g)) of the fruit.

# %%
O =  Orange[["Size (cm)","Weight (g)"]].corr()

# %%
O
# Out:
#             Size (cm)  Weight (g)
# Size (cm)    1.000000    0.305348
# Weight (g)   0.305348    1.000000

# %%
sns.barplot(data= O ,  x="Size (cm)",y="Weight (g)",hue = "Size (cm)")
# Out:
# <Axes: xlabel='Size (cm)', ylabel='Weight (g)'>

# %%
sns.boxplot(data= O ,  x="Size (cm)",y="Weight (g)",hue = "Size (cm)")
# Out:
# <Axes: xlabel='Size (cm)', ylabel='Weight (g)'>

# %% [markdown]
# ##  How does the sweetness (Brix) of the fruit correlate with its acidity (pH)? Do sweeter fruits have lower acidity.

# %%
Orange.head(1)
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
#
#    HarvestTime (days)  Ripeness (1-5)   Color   Variety Blemishes (Y/N)  \
# 0                  10             4.0  Orange  Valencia               N
#
#    Quality (1-5)
# 0            4.0

# %%
O1 =  Orange[["Brix (Sweetness)","pH (Acidity)"]].corr()

# %%
O1
# Out:
#                   Brix (Sweetness)  pH (Acidity)
# Brix (Sweetness)           1.00000      -0.30008
# pH (Acidity)              -0.30008       1.00000

# %%
sns.barplot(data=O1,x="Brix (Sweetness)",y="pH (Acidity)",hue="pH (Acidity)")
# Out:
# <Axes: xlabel='Brix (Sweetness)', ylabel='pH (Acidity)'>

# %%
sns.heatmap(O1,annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## How does the softness (Softness (1-5)) of the fruit relate to its ripeness (Ripeness (1-5))

# %%
Or = Orange[["Softness (1-5)","Ripeness (1-5)"]]

# %%
Or
# Out:
#      Softness (1-5)  Ripeness (1-5)
# 0               2.0             4.0
# 1               3.0             4.5
# 2               1.0             5.0
# 3               4.0             3.5
# 4               2.5             5.0
# ..              ...             ...
# 236             5.0             1.0
# 237             5.0             5.0
# 238             3.0             3.0
# 239             3.0             1.0
# 240             4.0             2.0
#
# [241 rows x 2 columns]

# %%
oo = Or.head(10)

# %%
oo
# Out:
#    Softness (1-5)  Ripeness (1-5)
# 0             2.0             4.0
# 1             3.0             4.5
# 2             1.0             5.0
# 3             4.0             3.5
# 4             2.5             5.0
# 5             2.0             2.0
# 6             3.5             4.0
# 7             1.5             4.5
# 8             5.0             3.0
# 9             2.0             4.5

# %%
sns.barplot(data =oo ,x = "Softness (1-5)",y= "Ripeness (1-5)",hue = "Ripeness (1-5)")
# Out:
# <Axes: xlabel='Softness (1-5)', ylabel='Ripeness (1-5)'>

# %% [markdown]
# ## Do fruits with blemishes (Blemishes (Y/N)) tend to have lower ripeness or softness levels

# %%
Oo = Orange[["Blemishes (Y/N)","Ripeness (1-5)"]]

# %%
Oo
# Out:
#              Blemishes (Y/N)  Ripeness (1-5)
# 0                          N             4.0
# 1                          N             4.5
# 2                          N             5.0
# 3                          N             3.5
# 4                  Y (Minor)             5.0
# ..                       ...             ...
# 236                Y (Scars)             1.0
# 237                        N             5.0
# 238  Y (Minor Insect Damage)             3.0
# 239  Y (Minor Insect Damage)             1.0
# 240                Y (Minor)             2.0
#
# [241 rows x 2 columns]

# %%
sns.pairplot(Orange[["Blemishes (Y/N)","Ripeness (1-5)","Softness (1-5)"]],hue = "Blemishes (Y/N)")
plt.show()

# %%
sns.barplot(data =Oo ,x = "Blemishes (Y/N)",y= "Ripeness (1-5)",hue = "Ripeness (1-5)")
# Out:
# <Axes: xlabel='Blemishes (Y/N)', ylabel='Ripeness (1-5)'>

# %% [markdown]
# ## How do different fruit varieties (Variety) differ in terms of size, weight, sweetness, acidity, and ripeness

# %%
Oranges = Orange.groupby("Variety")["Size (cm)"].sum().reset_index()

# %%
Oranges
# Out:
#                   Variety  Size (cm)
# 0                Ambiance       86.1
# 1            Blood Orange       19.0
# 2     California Valencia       55.2
# 3               Cara Cara      176.8
# 4              Clementine      106.1
# 5   Clementine (Seedless)       26.0
# 6                  Hamlin       40.8
# 7         Honey Tangerine       54.2
# 8                   Jaffa       78.0
# 9       Midsweet (Hybrid)       43.3
# 10      Minneola (Hybrid)       92.2
# 11           Moro (Blood)      135.6
# 12       Murcott (Hybrid)       23.2
# 13                  Navel      122.6
# 14   Navel (Early Season)       15.7
# 15    Navel (Late Season)       25.2
# 16     Ortanique (Hybrid)       93.8
# 17       Satsuma Mandarin       91.5
# 18              Star Ruby      152.0
# 19       Tangelo (Hybrid)        7.2
# 20              Tangerine      106.5
# 21                 Temple      137.5
# 22               Valencia       87.2
# 23       Washington Navel      114.9

# %%
sns.barplot(data =Oranges,y = "Variety",x = "Size (cm)",hue = "Variety")
# Out:
# <Axes: xlabel='Size (cm)', ylabel='Variety'>

# %%
Oranges1 = Orange.groupby("Variety")["Weight (g)"].sum().reset_index()

# %%
Oranges1
# Out:
#                   Variety  Weight (g)
# 0                Ambiance        2178
# 1            Blood Orange         550
# 2     California Valencia        1350
# 3               Cara Cara        4769
# 4              Clementine        3150
# 5   Clementine (Seedless)         520
# 6                  Hamlin        1035
# 7         Honey Tangerine        1299
# 8                   Jaffa        2210
# 9       Midsweet (Hybrid)        1135
# 10      Minneola (Hybrid)        2304
# 11           Moro (Blood)        3609
# 12       Murcott (Hybrid)         560
# 13                  Navel        3294
# 14   Navel (Early Season)         385
# 15    Navel (Late Season)         640
# 16     Ortanique (Hybrid)        2493
# 17       Satsuma Mandarin        2604
# 18              Star Ruby        4047
# 19       Tangelo (Hybrid)         160
# 20              Tangerine        2464
# 21                 Temple        3964
# 22               Valencia        2125
# 23       Washington Navel        2591

# %%
sns.barplot(data =Oranges1,y = "Variety",x = "Weight (g)",hue = "Weight (g)")
# Out:
# <Axes: xlabel='Weight (g)', ylabel='Variety'>

# %%
Oranges2 = Orange.groupby("Variety")["Brix (Sweetness)"].sum().reset_index()

# %%
Oranges2
# Out:
#                   Variety  Brix (Sweetness)
# 0                Ambiance             127.2
# 1            Blood Orange              15.5
# 2     California Valencia              72.5
# 3               Cara Cara             196.8
# 4              Clementine             159.2
# 5   Clementine (Seedless)              54.5
# 6                  Hamlin              54.5
# 7         Honey Tangerine              81.4
# 8                   Jaffa             110.3
# 9       Midsweet (Hybrid)              44.5
# 10      Minneola (Hybrid)             123.1
# 11           Moro (Blood)             159.1
# 12       Murcott (Hybrid)              37.0
# 13                  Navel             171.4
# 14   Navel (Early Season)              23.5
# 15    Navel (Late Season)              24.0
# 16     Ortanique (Hybrid)             135.8
# 17       Satsuma Mandarin             167.6
# 18              Star Ruby             185.8
# 19       Tangelo (Hybrid)               9.0
# ...

# %%
sns.barplot(data =Oranges2,y = "Variety",x = "Brix (Sweetness)",hue = "Brix (Sweetness)")
# Out:
# <Axes: xlabel='Brix (Sweetness)', ylabel='Variety'>

# %%
Oranges3 = Orange.groupby("Variety")["pH (Acidity)"].sum().reset_index()

# %%
Oranges3
# Out:
#                   Variety  pH (Acidity)
# 0                Ambiance         36.84
# 1            Blood Orange          7.90
# 2     California Valencia         23.20
# 3               Cara Cara         78.87
# 4              Clementine         48.01
# 5   Clementine (Seedless)         11.70
# 6                  Hamlin         16.50
# 7         Honey Tangerine         22.09
# 8                   Jaffa         35.88
# 9       Midsweet (Hybrid)         18.50
# 10      Minneola (Hybrid)         42.35
# 11           Moro (Blood)         62.26
# 12       Murcott (Hybrid)          9.30
# 13                  Navel         57.09
# 14   Navel (Early Season)          6.50
# 15    Navel (Late Season)         11.50
# 16     Ortanique (Hybrid)         48.48
# 17       Satsuma Mandarin         43.58
# 18              Star Ruby         60.10
# 19       Tangelo (Hybrid)          3.50
# 20              Tangerine         48.20
# 21                 Temple         61.03
# ...

# %%
sns.barplot(data =Oranges3,y = "Variety",x = "pH (Acidity)",hue = "pH (Acidity)")
# Out:
# <Axes: xlabel='pH (Acidity)', ylabel='Variety'>

# %%
Oranges4 = Orange.groupby("Variety")["Ripeness (1-5)"].sum().reset_index()

# %%
Oranges4
# Out:
#                   Variety  Ripeness (1-5)
# 0                Ambiance            36.5
# 1            Blood Orange             6.5
# 2     California Valencia            29.5
# 3               Cara Cara            70.5
# 4              Clementine            54.0
# 5   Clementine (Seedless)            19.5
# 6                  Hamlin            21.5
# 7         Honey Tangerine            31.0
# 8                   Jaffa            45.0
# 9       Midsweet (Hybrid)            18.0
# 10      Minneola (Hybrid)            41.0
# 11           Moro (Blood)            41.5
# 12       Murcott (Hybrid)            13.5
# 13                  Navel            63.5
# 14   Navel (Early Season)             8.5
# 15    Navel (Late Season)            10.0
# 16     Ortanique (Hybrid)            46.0
# 17       Satsuma Mandarin            49.0
# 18              Star Ruby            60.0
# 19       Tangelo (Hybrid)             4.0
# 20              Tangerine            46.0
# ...

# %%
sns.barplot(data =Oranges4,y = "Variety",x = "Ripeness (1-5)",hue = "Ripeness (1-5)")
# Out:
# <Axes: xlabel='Ripeness (1-5)', ylabel='Variety'>
